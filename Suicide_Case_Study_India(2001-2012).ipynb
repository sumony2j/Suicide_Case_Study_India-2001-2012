# %% [markdown]
# # In this project we are analysing Suicide cases in India from 2001 to 2012

# %% [markdown]
# # Introduction :
#
#                       Suicide is an irrational desire to die. We use the term “irrational” here because no matter how bad a person’s life is, suicide is a permanent solution to what is nearly always a temporary problem.
#
# Suicide is a symptom and sign of serious depression. Depression is a treatable disorder, but often the treatment takes time, energy and effort on the part of the person who’s feeling depressed. Sometimes, as a person who is depressed feels the energizing effects of an antidepressant medication, they will still feel depressed, but have more energy. It is during this time in treatment that many people turn to suicide and suicidal acts.
#
# Suicide’s effects are tragic and felt long after the individual has taken his or her own life. It is usually the second or third leading cause of death among teenagers, and remains one of the top ten leading causes of death well into middle age. A person who dies by suicide leaves behind them a tangled confusion of family members and friends who try to make sense of a senseless and purposeless act.
#
# Most people who think about suicide, however, never make a “serious” attempt at it (every attempt, though, is viewed as “serious” by the person making it). For every attempted suicide, there is thought to be one or more people where the thought of suicide has never translated into an actual attempt. With over a half a million people making a suicidal attempt each year, this translates into a huge problem that society largely ignores or tries to sweep under the rug. Prevention efforts largely target teenagers, but few professionals feel comfortable dealing with people who are actively suicidal. In most communities, the health care system also is not well-equipped to deal with the magnitude of the problem or the specific needs of a person who is suicidal.
#
# Suicidal behavior is complex. Some risk factors vary with age, gender and ethnic group and may even change over time. The risk factors for suicide frequently occur in combination. Research has shown that 90 percent of people who kill themselves have depression or another diagnosable mental or substance abuse disorder.
#
# Adverse life events in combination with other strong risk factors, such as depression, may lead to suicide. Suicide and suicidal behavior, however, are not normal responses to the stresses experienced by most people. Most people who experience one or more risk factors do not become suicidal. Other risk factors include:
#
# Prior suicide attempt
# Family history of mental or substance abuse disorder
# Family history of suicide
# Family violence, including physical or sexual abuse
# Firearms in the home
# Incarceration
# Exposure to the suicidal behavior of others, including family members, peers or via the media in news or fiction stories.

# %% [markdown]
# # Data Analysis ------------------

# %% [markdown]
# #  Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib Notebook
# %matplotlib inline

# %% [markdown]
# # Read CSV File

# %%
df=pd.read_csv('Suicidesindia2001-2012.csv')

# %%
df.shape
# Out:
# (237519, 7)

# %%
df
# Out:
#                 State  Year      Type_code  \
# 0       A & N Islands  2001         Causes
# 1       A & N Islands  2001         Causes
# 2       A & N Islands  2001         Causes
# 3       A & N Islands  2001         Causes
# 4       A & N Islands  2001         Causes
# ...               ...   ...            ...
# 237514    West Bengal  2012  Social_Status
# 237515    West Bengal  2012  Social_Status
# 237516    West Bengal  2012  Social_Status
# 237517    West Bengal  2012  Social_Status
# 237518    West Bengal  2012  Social_Status
#
#                                            Type  Gender Age_group  Total
# 0                            Illness (Aids/STD)  Female      0-14      0
# 1       Bankruptcy or Sudden change in Economic  Female      0-14      0
# 2       Cancellation/Non-Settlement of Marriage  Female      0-14      0
# 3             Physical Abuse (Rape/Incest Etc.)  Female      0-14      0
# 4                                 Dowry Dispute  Female      0-14      0
# ...

# %% [markdown]
# ## Clearing data

# %%
df['State'].unique()
# Out:
# array(['A & N Islands', 'Andhra Pradesh', 'Arunachal Pradesh', 'Assam',
#        'Bihar', 'Chandigarh', 'Chhattisgarh', 'D & N Haveli',
#        'Daman & Diu', 'Delhi (Ut)', 'Goa', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand', 'Karnataka',
#        'Kerala', 'Lakshadweep', 'Madhya Pradesh', 'Maharashtra',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha',
#        'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu',
#        'Total (All India)', 'Total (States)', 'Total (Uts)', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal'], dtype=object)

# %%
df.set_index('State',inplace=True)

# %%
df.drop(['Total (All India)', 'Total (States)', 'Total (Uts)'],inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df['State'].unique()
# Out:
# array(['A & N Islands', 'Andhra Pradesh', 'Arunachal Pradesh', 'Assam',
#        'Bihar', 'Chandigarh', 'Chhattisgarh', 'D & N Haveli',
#        'Daman & Diu', 'Delhi (Ut)', 'Goa', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand', 'Karnataka',
#        'Kerala', 'Lakshadweep', 'Madhya Pradesh', 'Maharashtra',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha',
#        'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
df.shape
# Out:
# (236583, 7)

# %% [markdown]
# #  Show top 10 data

# %%
df.head(10)
# Out:
#            State  Year Type_code                                     Type  \
# 0  A & N Islands  2001    Causes                       Illness (Aids/STD)
# 1  A & N Islands  2001    Causes  Bankruptcy or Sudden change in Economic
# 2  A & N Islands  2001    Causes  Cancellation/Non-Settlement of Marriage
# 3  A & N Islands  2001    Causes        Physical Abuse (Rape/Incest Etc.)
# 4  A & N Islands  2001    Causes                            Dowry Dispute
# 5  A & N Islands  2001    Causes                          Family Problems
# 6  A & N Islands  2001    Causes      Ideological Causes/Hero Worshipping
# 7  A & N Islands  2001    Causes                  Other Prolonged Illness
# 8  A & N Islands  2001    Causes                         Property Dispute
# 9  A & N Islands  2001    Causes                Fall in Social Reputation
#
#    Gender Age_group  Total
# 0  Female      0-14      0
# 1  Female      0-14      0
# 2  Female      0-14      0
# 3  Female      0-14      0
# ...

# %% [markdown]
# # Show bottom 10 data

# %%
df.tail(10)
# Out:
#               State  Year      Type_code             Type  Gender Age_group  \
# 236573  West Bengal  2012  Social_Status        Seperated  Female    0-100+
# 236574  West Bengal  2012  Social_Status          Married  Female    0-100+
# 236575  West Bengal  2012  Social_Status         Divorcee  Female    0-100+
# 236576  West Bengal  2012  Social_Status  Widowed/Widower  Female    0-100+
# 236577  West Bengal  2012  Social_Status    Never Married  Female    0-100+
# 236578  West Bengal  2012  Social_Status        Seperated    Male    0-100+
# 236579  West Bengal  2012  Social_Status  Widowed/Widower    Male    0-100+
# 236580  West Bengal  2012  Social_Status          Married    Male    0-100+
# 236581  West Bengal  2012  Social_Status         Divorcee    Male    0-100+
# 236582  West Bengal  2012  Social_Status    Never Married    Male    0-100+
#
#         Total
# 236573    200
# 236574   3927
# 236575    182
# 236576    455
# 236577   1513
# 236578    149
# 236579    233
# ...

# %% [markdown]
# # Columns of Dataset

# %%
df.columns
# Out:
# Index(['State', 'Year', 'Type_code', 'Type', 'Gender', 'Age_group', 'Total'], dtype='object')

# %% [markdown]
# # Find datatype of each columns

# %%
df.dtypes
# Out:
# State        object
# Year          int64
# Type_code    object
# Type         object
# Gender       object
# Age_group    object
# Total         int64
# dtype: object

# %% [markdown]
# # Find the statistic of each columns

# %%
 df.describe(include='all')
# Out:
#               State          Year Type_code                     Type  Gender  \
# count        236583  236583.00000    236583                   236583  236583
# unique           35           NaN         5                       69       2
# top     Maharashtra           NaN    Causes  Others (Please Specify)    Male
# freq           6792           NaN    109200                     7263  118411
# mean            NaN    2006.50045       NaN                      NaN     NaN
# std             NaN       3.45224       NaN                      NaN     NaN
# min             NaN    2001.00000       NaN                      NaN     NaN
# 25%             NaN    2004.00000       NaN                      NaN     NaN
# 50%             NaN    2007.00000       NaN                      NaN     NaN
# 75%             NaN    2010.00000       NaN                      NaN     NaN
# max             NaN    2012.00000       NaN                      NaN     NaN
#
#        Age_group          Total
# ...

# %% [markdown]
# # Find information of Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236583 entries, 0 to 236582
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   State      236583 non-null  object
#  1   Year       236583 non-null  int64
#  2   Type_code  236583 non-null  object
#  3   Type       236583 non-null  object
#  4   Gender     236583 non-null  object
#  5   Age_group  236583 non-null  object
#  6   Total      236583 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 12.6+ MB

# %% [markdown]
# # Find Null Values in the Dataset

# %%
df[df.isnull()].count()
# Out:
# State        0
# Year         0
# Type_code    0
# Type         0
# Gender       0
# Age_group    0
# Total        0
# dtype: int64

# %% [markdown]
# ## Questions -------------

# %% [markdown]
# # Find Total Number of Suicides in India from 2001-2012

# %%
df['Total'].sum()
# Out:
# 7248010

# %% [markdown]
# # Find Total Number of Suicides each year from 2001-2012

# %%
df_year=df['Total'].groupby(df['Year']).sum()
df_year=df_year.to_frame()
df_year.reset_index(inplace=True)
df_year
# Out:
#     Year   Total
# 0   2001  542440
# 1   2002  551980
# 2   2003  554218
# 3   2004  568349
# 4   2005  569545
# 5   2006  590543
# 6   2007  613119
# 7   2008  625014
# 8   2009  635429
# 9   2010  672926
# 10  2011  677159
# 11  2012  647288

# %%
x=df_year['Year']
y=df_year['Total']
plt.style.use('dark_background')
plt.figure(figsize=(18,6))
sns.lineplot(x,y,color='yellow')
plt.xlabel('YEARS(2001-2012)',fontweight='bold',fontsize=20,color='green')
plt.ylabel('NUMBER OF SUICIDES EACH YEARS',fontweight='bold',fontsize=20,color='green')
plt.title('TOTAL SUICIDES EACH YEAR',fontweight='bold',fontsize=26,color='blue')
plt.xticks(fontweight='bold',fontsize=14,)
plt.yticks(fontweight='bold',fontsize=14)
# Out:
# (array([520000., 540000., 560000., 580000., 600000., 620000., 640000.,
#         660000., 680000., 700000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # Find Total Number of Suicides at each states  from 2001-2012

# %%
df_state=df['Total'].groupby(df['State']).sum()
df_state=df_state.to_frame()
df_state.reset_index(inplace=True)
df_state.sort_values(by='Total')
# Out:
#                 State   Total
# 18        Lakshadweep      50
# 8         Daman & Diu    1391
# 24           Nagaland    1728
# 21            Manipur    2102
# 7        D & N Haveli    3430
# 23            Mizoram    4154
# 5          Chandigarh    5164
# 22          Meghalaya    5415
# 2   Arunachal Pradesh    6633
# 0       A & N Islands    8109
# 29             Sikkim    9606
# 14    Jammu & Kashmir   14821
# 10                Goa   17363
# 33        Uttarakhand   18496
# 13   Himachal Pradesh   26562
# 26         Puducherry   32144
# 31            Tripura   45965
# 4               Bihar   46214
# 27             Punjab   46350
# 15          Jharkhand   49720
# 9          Delhi (Ut)   84272
# 12            Haryana  147176
# 3               Assam  172276
# 32      Uttar Pradesh  233352
# 28          Rajasthan  255134
# 25             Odisha  267234
# 6        Chhattisgarh  302354
# 11            Gujarat  330858
# 19     Madhya Pradesh  451535
# 17             Kerala  538946
# ...

# %%
x=df_state['State']
y=df_state['Total']
plt.figure(figsize=(15,6))
f=sns.barplot(x,y,palette='Set1')
f.set_xticklabels(f.get_xticklabels(),rotation=90,fontweight='bold',fontsize=14)
f.set_title('TOTAL SUICIDES AT EACH STATE',fontweight='bold',color='red',fontsize=26)
plt.xlabel('State',fontweight='bold',fontsize=20,color='orange')
plt.ylabel('Number Of Suicides',fontweight='bold',fontsize='20',color='orange')
plt.yticks(fontweight='bold',fontsize=14)
# Out:
# (array([      0.,  200000.,  400000.,  600000.,  800000., 1000000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # Find Total Number of Suicides of each age group from 2001-2012

# %%
df_age=df['Total'].groupby(df['Age_group']).sum()
df_age=df_age.to_frame()
df_age.reset_index(inplace=True)
df_age.drop(0,inplace=True)
df_age.reset_index(drop=True,inplace=True)
df_age
# Out:
#   Age_group    Total
# 0      0-14    98410
# 1     15-29  1534037
# 2     30-44  1471599
# 3     45-59   885177
# 4       60+   346925

# %%
x=df_age['Age_group']
y=df_age['Total']
plt.figure(figsize=(15,5))
sns.barplot(x,y,palette='dark')
plt.xlabel('Age Group',fontweight='bold',color='blue',fontsize=20)
plt.ylabel('Number Of Suicides Each Year',fontweight='bold',color="blue",fontsize=20)
plt.title('Total Suicides Each Year',fontweight='bold',color='red',fontsize=26)
plt.xticks(fontweight='bold',fontsize=14)
plt.yticks(fontweight='bold',fontsize=14)
# Out:
# (array([      0.,  200000.,  400000.,  600000.,  800000., 1000000.,
#         1200000., 1400000., 1600000., 1800000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # Find Total Number of Suicides of each gender from 2001-2012

# %%
df_Gender=df['Total'].groupby(df['Gender']).sum()
df_Gender
# Out:
# Gender
# Female    2606922
# Male      4641088
# Name: Total, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.pie(df_Gender,labels=df_Gender.index,explode=[0.1,0],autopct='%3.1f%%',shadow=True,startangle=135,colors=['lightblue','lightgreen'],textprops={'fontsize':20,'fontweight':'bold','color':'red'})
plt.title('Number Of Suicides Cases Of Each Gender',fontweight='bold',fontsize=26,color='orange')
plt.legend()

# %% [markdown]
# # Find Total Suicide Cases In India State-Year Wise

# %%
df_sy=df['Total'].groupby([df['State'],df['Year']]).sum()
df_sy=df_sy.to_frame()
df_sy.reset_index(inplace=True)
df_sy
# Out:
#              State  Year  Total
# 0    A & N Islands  2001    645
# 1    A & N Islands  2002    720
# 2    A & N Islands  2003    565
# 3    A & N Islands  2004    610
# 4    A & N Islands  2005    695
# ..             ...   ...    ...
# 415    West Bengal  2008  74260
# 416    West Bengal  2009  73240
# 417    West Bengal  2010  80185
# 418    West Bengal  2011  82460
# 419    West Bengal  2012  44871
#
# [420 rows x 3 columns]

# %%
plt.figure(figsize=(115,10))
f=sns.barplot(x='State',y='Total',hue='Year',data=df_sy,palette='Set1')
plt.xlabel('Age Group',fontweight='bold',color='blue',fontsize=20)
plt.ylabel('Number Of Suicides Each Year',fontweight='bold',color="blue",fontsize=20)
plt.title('Total Suicides Each Year',fontweight='bold',color='red',fontsize=26)
plt.xticks(fontweight='bold',fontsize=14,rotation=90)
plt.yticks(fontweight='bold',fontsize=14)
# Out:
# (array([    0., 10000., 20000., 30000., 40000., 50000., 60000., 70000.,
#         80000., 90000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # Find Total Suicide Cases In India State-Gender Wise

# %%
df_sg=df['Total'].groupby([df['State'],df['Gender']]).sum()
df_sg=df_sg.to_frame()
df_sg.reset_index(inplace=True)
df_sg
# Out:
#                 State  Gender   Total
# 0       A & N Islands  Female    2750
# 1       A & N Islands    Male    5359
# 2      Andhra Pradesh  Female  271939
# 3      Andhra Pradesh    Male  542120
# 4   Arunachal Pradesh  Female    1954
# ..                ...     ...     ...
# 65      Uttar Pradesh    Male  125327
# 66        Uttarakhand  Female    7548
# 67        Uttarakhand    Male   10948
# 68        West Bengal  Female  365241
# 69        West Bengal    Male  484695
#
# [70 rows x 3 columns]

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='State',y='Total',hue='Gender',data=df_sg,palette='bright')
plt.xlabel('State',fontweight='bold',color='#03fcc2',fontsize=20)
plt.ylabel('Number Of Suicides Each Year',fontweight='bold',color="#03fcc2",fontsize=20)
plt.title('Total Suicides With Respect To Each Gender In Each State',fontweight='bold',color='red',fontsize=26)
plt.xticks(fontweight='bold',fontsize=14,rotation=90)
plt.yticks(fontweight='bold',fontsize=14)
# Out:
# (array([     0., 100000., 200000., 300000., 400000., 500000., 600000.,
#         700000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # Find Total Suicide Cases In India Year-Gender Wise

# %%
df_yg=df['Total'].groupby([df['Year'],df['Gender']]).sum()
df_yg=df_yg.to_frame()
df_yg.reset_index(inplace=True)
df_yg
# Out:
#     Year  Gender   Total
# 0   2001  Female  210877
# 1   2001    Male  331563
# 2   2002  Female  205335
# 3   2002    Male  346645
# 4   2003  Female  203137
# 5   2003    Male  351081
# 6   2004  Female  205113
# 7   2004    Male  363236
# 8   2005  Female  204988
# 9   2005    Male  364557
# 10  2006  Female  212037
# 11  2006    Male  378506
# 12  2007  Female  216664
# 13  2007    Male  396455
# 14  2008  Female  222310
# 15  2008    Male  402704
# 16  2009  Female  228330
# 17  2009    Male  407099
# 18  2010  Female  237029
# 19  2010    Male  435897
# 20  2011  Female  238704
# 21  2011    Male  438455
# 22  2012  Female  222398
# 23  2012    Male  424890

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='Year',y='Total',hue="Gender",data=df_yg,palette='YlOrRd')
plt.xlabel('Year',fontweight='bold',color='blue',fontsize=20)
plt.ylabel('Number Of Suicides Each Year',fontweight='bold',color="blue",fontsize=20)
plt.title('Total Suicides Of Each Gender In Each Year',fontweight='bold',color='red',fontsize=26)
plt.xticks(fontweight='bold',fontsize=14)
plt.yticks(fontweight='bold',fontsize=14)
# Out:
# (array([     0., 100000., 200000., 300000., 400000., 500000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # Find Total Suicide Cases In India State-Year-Gender Wise

# %%
df_syg=df['Total'].groupby([df['State'],df['Year'],df['Gender']]).sum()
df_syg=df_syg.to_frame()
df_syg.reset_index(inplace=True)
df_syg=pd.pivot_table(df_syg,index='State',columns=['Year','Gender'],values='Total')
df_syg
# Out:
# Year                2001          2002          2003          2004         \
# Gender            Female   Male Female   Male Female   Male Female   Male
# State
# A & N Islands        250    395    265    455    215    350    205    405
# Andhra Pradesh     20715  31895  20610  37855  19480  37565  22220  45410
# Arunachal Pradesh    175    380    215    355    135    270    150    245
# Assam               4050   9180   4040   8510   4600   8363   4453   9725
# Bihar               1480   1535   1470   2130   1229   1755    695   1060
# Chandigarh           155    195    170    265    175    340    115    260
# Chhattisgarh        6851  13200   6605  13145   6635  12960   7545  14930
# D & N Haveli          75    175     90    160    110    150     95    100
# Daman & Diu           20     49     10     75     30     88     40     25
# Delhi (Ut)          2545   3650   2050   3215   2060   3705   2283   3994
# Goa                  445    835    415   1130    435   1065    510   1060
# ...

# %% [markdown]
# # Find Total Suicide Cases In India Based On Casues Of Suicide

# %%
df_causes=df['Total'][df['Type_code']=='Causes'].groupby(df['Type']).sum().sort_values(ascending=False)
df_causes
# Out:
# Type
# Family Problems                                   341952
# Causes Not known                                  237069
# Other Causes (Please Specity)                     216050
# Other Prolonged Illness                           194565
# Insanity/Mental Illness                            94229
# Love Affairs                                       45039
# Bankruptcy or Sudden change in Economic            32755
# Poverty                                            32684
# Dowry Dispute                                      31970
# Drug Abuse/Addiction                               30046
# Unemployment                                       27365
# Failure in Examination                             27005
# Property Dispute                                   18652
# Suspected/Illicit Relation                         14911
# Fall in Social Reputation                          13464
# Professional/Career Problem                        12554
# ...

# %%
plt.figure(figsize=(12,10))
df_causes.plot(kind='barh',color='blue')
plt.xticks(fontweight='bold',fontsize=10)
plt.yticks(fontweight='bold',fontsize=10)
plt.title('Total Number Of Suicides VS Reasons Of Suicide',fontweight='bold',fontsize=26,color='orange')
plt.xlabel('Number Of Suicides',fontweight='bold',fontsize=20,color='red')
plt.ylabel('Reason Of Suicides',fontweight='bold',fontsize=20,color='red')
# Out:
# Text(0, 0.5, 'Reason Of Suicides')

# %% [markdown]
# # Find Total Suicide Cases In India Based On Educational Status of victims

# %%
df_edusta=df['Total'][df['Type_code']=='Education_Status'].groupby(df['Type']).sum().sort_values(ascending=False)
df_edusta
# Out:
# Type
# Primary                                     362827
# Middle                                      342971
# No Education                                321757
# Matriculate/Secondary                       256566
# Hr. Secondary/Intermediate/Pre-Universit    118908
# Graduate                                     31274
# Diploma                                      14153
# Post Graduate and Above                       7475
# Name: Total, dtype: int64

# %%
plt.figure(figsize=(12,6))
df_edusta.plot(kind='barh',color='#48a832')
plt.ylabel('Educational Status',fontweight='bold',color='orange',fontsize=20)
plt.xlabel('Number Of Suicides',fontweight='bold',color="orange",fontsize=20)
plt.title('Total Suicides Based On Educational Status',fontweight='bold',color='red',fontsize=26)
plt.xticks(fontweight='bold',fontsize=14)
plt.yticks(fontweight='bold',fontsize=14)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, 'Primary'),
#   Text(0, 1, 'Middle'),
#   Text(0, 2, 'No Education'),
#   Text(0, 3, 'Matriculate/Secondary'),
#   Text(0, 4, 'Hr. Secondary/Intermediate/Pre-Universit'),
#   Text(0, 5, 'Graduate'),
#   Text(0, 6, 'Diploma'),
#   Text(0, 7, 'Post Graduate and Above')])

# %% [markdown]
# # Find Total Suicide Cases In India Based On Social Status of victims

# %%
df_ss=df['Total'][df['Type_code']=='Social_Status'].groupby(df['Type']).sum().sort_values(ascending=False)
df_ss
# Out:
# Type
# Married            1021774
# Never Married       318301
# Widowed/Widower      62113
# Seperated            38471
# Divorcee             15272
# Name: Total, dtype: int64

# %%
plt.figure(figsize=(12,8))
plt.pie(df_ss,labels=df_ss.index,shadow=True,autopct='%1.0f%%',startangle=135,colors=["c", 'b','r','y','g'],textprops={'fontsize':12,'fontweight':'bold','color':'#2b4066'},radius=0.8,explode=[0.1,0.1,0.3,0.3,0.3])
plt.legend()

# %% [markdown]
# # Find Total Suicide Cases In India Based On Professional Profile of victims

# %%
df_pp=df['Total'][df['Type_code']=='Professional_Profile'].groupby(df['Type']).sum().sort_values(ascending=False)
df_pp
# Out:
# Type
# Others (Please Specify)              469147
# House Wife                           285243
# Farming/Agriculture Activity         197923
# Service (Private)                    115472
# Unemployed                           114374
# Self-employed (Business activity)     78112
# Student                               74323
# Professional Activity                 39204
# Public Sector Undertaking             30786
# Service (Government)                  23325
# Retired Person                        11334
# Name: Total, dtype: int64

# %%
plt.figure(figsize=(18,8))
df_pp.plot(kind='bar',color='gray')
plt.xlabel('Profession',fontweight='bold',color='orange',fontsize=20)
plt.ylabel('Number Of Suicides Each Year Of Male',fontweight='bold',color="orange",fontsize=20)
plt.title('Total Suicides based on Professional profile',fontweight='bold',color='red',fontsize=26)
plt.xticks(fontweight='bold',fontsize=14)
plt.yticks(fontweight='bold',fontsize=14)
# Out:
# (array([     0., 100000., 200000., 300000., 400000., 500000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # Find Total Suicide Cases In India Based On  Method Used For Suicide

# %%
df_sm=df['Total'][df['Type_code']=='Means_adopted'].groupby(df['Type']).sum().sort_values(ascending=False)
df_sm=df_sm.to_frame()
df_sm.reset_index(inplace=True)
df_sm
# Out:
#                                        Type   Total
# 0                                By Hanging  460955
# 1                 By Consuming Insecticides  275501
# 2                 By Consuming Other Poison  231178
# 3           By Other means (please specify)  135132
# 4                   By Fire/Self Immolation  128006
# 5                               By Drowning   96711
# 6   By coming under running vehicles/trains   45299
# 7                        By Over Alcoholism   15973
# 8                By touching electric wires   10816
# 9             By Overdose of sleeping pills    9960
# 10                           By Other means    9238
# 11            By Jumping from (Other sites)    8127
# 12    By Jumping off Moving Vehicles/Trains    8116
# 13               By Jumping from (Building)    7871
# 14                             By Fire-Arms    6294
# 15             By Self Infliction of injury    5093
# 16                               By Machine    1661

# %%
x=df_sm['Type']
y=df_sm['Total']
plt.figure(figsize=(15,5))
f=sns.barplot(x,y,palette='Set1')
f.set_xticklabels(f.get_xticklabels(),rotation=90,fontweight='bold')
f.set_title('METHODS USED FOR SUICIDE',fontweight='bold')
plt.xlabel('Methods Used For Suicide',fontweight='bold',color='blue',fontsize=20)
plt.ylabel('Number Of Suicides',fontweight='bold',color="blue",fontsize=20)
plt.title('Total Suicides VS Methods Used For Suicide',fontweight='bold',color='red',fontsize=26)
plt.xticks(fontweight='bold',fontsize=14,rotation=90)
plt.yticks(fontweight='bold',fontsize=14)
# Out:
# (array([     0., 100000., 200000., 300000., 400000., 500000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # Find how much female and male have commited suicide of each age from 2001-2012

# %%
df_afm=df['Total'].groupby([df['Age_group'],df['Gender']]).sum()
df_afm=df_afm.to_frame()
df_afm
# Out:
#                     Total
# Age_group Gender
# 0-100+    Female  1048026
#           Male    1863836
# 0-14      Female    49436
#           Male      48974
# 15-29     Female   701215
#           Male     832822
# 30-44     Female   477461
#           Male     994138
# 45-59     Female   232542
#           Male     652635
# 60+       Female    98242
#           Male     248683

# %%
df_afm.reset_index(inplace=True)
df_afm
# Out:
#    Age_group  Gender    Total
# 0     0-100+  Female  1048026
# 1     0-100+    Male  1863836
# 2       0-14  Female    49436
# 3       0-14    Male    48974
# 4      15-29  Female   701215
# 5      15-29    Male   832822
# 6      30-44  Female   477461
# 7      30-44    Male   994138
# 8      45-59  Female   232542
# 9      45-59    Male   652635
# 10       60+  Female    98242
# 11       60+    Male   248683

# %%
df_afm.drop(df_afm.index[0:2],inplace=True)
df_afm.reset_index(drop=True,inplace=True)
df_afm
# Out:
#   Age_group  Gender   Total
# 0      0-14  Female   49436
# 1      0-14    Male   48974
# 2     15-29  Female  701215
# 3     15-29    Male  832822
# 4     30-44  Female  477461
# 5     30-44    Male  994138
# 6     45-59  Female  232542
# 7     45-59    Male  652635
# 8       60+  Female   98242
# 9       60+    Male  248683

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Age_group',y='Total',hue='Gender',data=df_afm,palette='Paired')
plt.xlabel('Age Group',fontweight='bold',color='blue',fontsize=20)
plt.ylabel('Number Of Suicides',fontweight='bold',color="blue",fontsize=20)
plt.title('Total Suicides Of Each Gender Of Each Age',fontweight='bold',color='red',fontsize=26)
plt.xticks(fontweight='bold',fontsize=14)
plt.yticks(fontweight='bold',fontsize=14)
# Out:
# (array([      0.,  200000.,  400000.,  600000.,  800000., 1000000.,
#         1200000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # Find how different causes have affected suicide of female from 2001-2012

# %%
df_f=df[(df['Type_code']=='Causes') & (df['Gender']=='Female')]
df_f.reset_index(inplace=True)
df_f
# Out:
#         index          State  Year Type_code  \
# 0           0  A & N Islands  2001    Causes
# 1           1  A & N Islands  2001    Causes
# 2           2  A & N Islands  2001    Causes
# 3           3  A & N Islands  2001    Causes
# 4           4  A & N Islands  2001    Causes
# ...       ...            ...   ...       ...
# 54595  236256    West Bengal  2012    Causes
# 54596  236257    West Bengal  2012    Causes
# 54597  236258    West Bengal  2012    Causes
# 54598  236259    West Bengal  2012    Causes
# 54599  236260    West Bengal  2012    Causes
#
#                                           Type  Gender Age_group  Total
# 0                           Illness (Aids/STD)  Female      0-14      0
# 1      Bankruptcy or Sudden change in Economic  Female      0-14      0
# 2      Cancellation/Non-Settlement of Marriage  Female      0-14      0
# 3            Physical Abuse (Rape/Incest Etc.)  Female      0-14      0
# ...

# %%
df_f1=df_f['Total'].groupby(df_f['Type']).sum()
df_f1
# Out:
# Type
# Bankruptcy or Sudden change in Economic             3877
# Bankruptcy or Sudden change in Economic Status       358
# Cancellation/Non-Settlement of Marriage             6126
# Cancer                                              2878
# Causes Not known                                   76899
# Death of Dear Person                                4707
# Divorce                                             2535
# Dowry Dispute                                      31206
# Drug Abuse/Addiction                                1205
# Failure in Examination                             12054
# Fall in Social Reputation                           4697
# Family Problems                                   133181
# Ideological Causes/Hero Worshipping                  776
# Illegitimate Pregnancy                              2391
# Illness (Aids/STD)                                  2892
# Insanity/Mental Illness                            33352
# ...

# %%
plt.figure(figsize=(18,8))
df_f1.plot(kind='bar',color='yellow')
plt.xlabel('Reasons Of Suicide',fontweight='bold',color='blue',fontsize=20)
plt.ylabel('Number Of Suicides Each Year Of Female',fontweight='bold',color="blue",fontsize=20)
plt.title('Total Suicides Of Female Each Year VS Reasons Of Suicides',fontweight='bold',color='red',fontsize=26)
plt.xticks(fontweight='bold',fontsize=14)
plt.yticks(fontweight='bold',fontsize=14)
# Out:
# (array([     0.,  20000.,  40000.,  60000.,  80000., 100000., 120000.,
#         140000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# #  Find how different causes have affected suicide of male from 2001-2012

# %%
df_m=df[(df['Type_code']=='Causes') & (df['Gender']=='Male')]
df_m.reset_index(inplace=True)
df_m
# Out:
#         index          State  Year Type_code  \
# 0          26  A & N Islands  2001    Causes
# 1          27  A & N Islands  2001    Causes
# 2          28  A & N Islands  2001    Causes
# 3          29  A & N Islands  2001    Causes
# 4          30  A & N Islands  2001    Causes
# ...       ...            ...   ...       ...
# 54595  236282    West Bengal  2012    Causes
# 54596  236283    West Bengal  2012    Causes
# 54597  236284    West Bengal  2012    Causes
# 54598  236285    West Bengal  2012    Causes
# 54599  236286    West Bengal  2012    Causes
#
#                                            Type Gender Age_group  Total
# 0                              Property Dispute   Male      0-14      0
# 1                                  Unemployment   Male      0-14      0
# 2                                       Poverty   Male      0-14      0
# 3                               Family Problems   Male      0-14      0
# ...

# %%
df_m1=df_m['Total'].groupby(df_m['Type']).sum()
df_m1
# Out:
# Type
# Bankruptcy or Sudden change in Economic            28878
# Bankruptcy or Sudden change in Economic Status      2297
# Cancellation/Non-Settlement of Marriage             5170
# Cancer                                              6180
# Causes Not known                                  160170
# Death of Dear Person                                5614
# Divorce                                             1598
# Dowry Dispute                                        764
# Drug Abuse/Addiction                               28841
# Failure in Examination                             14951
# Fall in Social Reputation                           8767
# Family Problems                                   208771
# Ideological Causes/Hero Worshipping                 1342
# Illegitimate Pregnancy                               103
# Illness (Aids/STD)                                  5831
# Insanity/Mental Illness                            60877
# ...

# %%
plt.figure(figsize=(18,8))
df_m1.plot(kind='bar',color='green')
plt.xlabel('Reasons Of Suicide',fontweight='bold',color='blue',fontsize=20)
plt.ylabel('Number Of Suicides Each Year Of Male',fontweight='bold',color="blue",fontsize=20)
plt.title('Total Suicides Of Male Each Year VS Reasons Of Suicides',fontweight='bold',color='red',fontsize=26)
plt.xticks(fontweight='bold',fontsize=14)
plt.yticks(fontweight='bold',fontsize=14)
# Out:
# (array([     0.,  25000.,  50000.,  75000., 100000., 125000., 150000.,
#         175000., 200000., 225000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# # Conclusion :

# %% [markdown]
# ## After Analysis of the Dataset of Suicide cases in India from 2001-2012 ,We Came to know some really interesting facts as follows ------------------

# %% [markdown]
# ### 1> Total Number of suicide cases in India (2001-2012)  :- # 7248010

# %% [markdown]
# ### 2> Most suicide cases has been noticed in India (2001-2012) in year :- # 2011

# %% [markdown]
# ### 3> Top 3 states in India (2001-2012) reported for most suicide cases :- # A) Maharashtra B) West Bengal C) Tamil Nadu

# %% [markdown]
# ### 4> Top 3 states in India (2001-2012) reported for least suicide cases :- # A) Lakshadweep B) Daman & Diu C) Nagaland

# %% [markdown]
# ### 5> Most people committed suicide of age :- # 15-29

# %% [markdown]
# ### 6> Least people committed suicide of age :- # 0-14

# %% [markdown]
# ### 7> Number of male committed suicide is more than female

# %% [markdown]
# ### 8>Most female committed suicide of state :- # West Bengal

# %% [markdown]
# ### 9>Most male committed suicide of state :- # Maharashtra

# %% [markdown]
# ### 10>Most male committed suicide in year :- # 2011

# %% [markdown]
# ### 11>Most female committed suicide in year :- # 2011

# %% [markdown]
# ### 12>Reason for most of suicide cases :- # Family problem

# %% [markdown]
# ### 13>Educational qualification of most of suicide victims :- # Primary

# %% [markdown]
# ### 14>Most of the suicide victims are married

# %% [markdown]
# ### 15> Most people committed suicide by hanging

# %% [markdown]
# ### 16> Most male has committed suicide of age 35-44

# %% [markdown]
# ### 16> Most female has committed suicide of age 15-29

# %% [markdown]
# ### 17> Both most male and female committed suicide due to family problems
